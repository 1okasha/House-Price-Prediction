# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.drop(["id"],axis=1,inplace=True)

# %%
df
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900.0         3       1.00         1180      5650
# 1      20141209T000000  538000.0         3       2.25         2570      7242
# 2      20150225T000000  180000.0         2       1.00          770     10000
# 3      20141209T000000  604000.0         4       3.00         1960      5000
# 4      20150218T000000  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 21608  20140521T000000  360000.0         3       2.50         1530      1131
# 21609  20150223T000000  400000.0         4       2.50         2310      5813
# 21610  20140623T000000  402101.0         2       0.75         1020      1350
# 21611  20150116T000000  400000.0         3       2.50         1600      2388
# 21612  20141015T000000  325000.0         2       0.75         1020      1076
#
# ...

# %%
df = df.drop(columns="date")

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308326   0.525146     0.702035  0.089652  0.256893
# bedrooms       0.308326  1.000000   0.515956     0.576640  0.031671  0.175608
# bathrooms      0.525146  0.515956   1.000000     0.754717  0.087751  0.500754
# sqft_living    0.702035  0.576640   0.754717     1.000000  0.172809  0.354181
# sqft_lot       0.089652  0.031671   0.087751     0.172809  1.000000 -0.005113
# floors         0.256893  0.175608   0.500754     0.354181 -0.005113  1.000000
# waterfront     0.266371 -0.006591   0.063747     0.103817  0.021598  0.023731
# view           0.397409  0.079411   0.187892     0.284627  0.074744  0.029383
# condition      0.036345  0.028370  -0.124941    -0.058825 -0.008988 -0.263728
# grade          0.667541  0.357143   0.665029     0.762893  0.113688  0.458074
# sqft_above     0.605559  0.477569   0.685376     0.876593  0.183508  0.524117
# ...

# %%
st=["sqft_lot15","zipcode","condition","sqft_lot"]

# %%
df.drop(df[st],axis=1,inplace=True)
# Out:
# <ipython-input-20-ade14cb8f348>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[st],axis=1,inplace=True)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# 0      221900.0         3       1.00         1180     1.0           0     0
# 1      538000.0         3       2.25         2570     2.0           0     0
# 2      180000.0         2       1.00          770     1.0           0     0
# 3      604000.0         4       3.00         1960     1.0           0     0
# 4      510000.0         3       2.00         1680     1.0           0     0
# ...         ...       ...        ...          ...     ...         ...   ...
# 21608  360000.0         3       2.50         1530     3.0           0     0
# 21609  400000.0         4       2.50         2310     2.0           0     0
# 21610  402101.0         2       0.75         1020     2.0           0     0
# 21611  400000.0         3       2.50         1600     2.0           0     0
# 21612  325000.0         2       0.75         1020     2.0           0     0
#
# ...

# %%
sns.set (rc = {'figure.figsize':(30, 20)})
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living    floors  \
# price          1.000000  0.308326   0.525146     0.702035  0.256893
# bedrooms       0.308326  1.000000   0.515956     0.576640  0.175608
# bathrooms      0.525146  0.515956   1.000000     0.754717  0.500754
# sqft_living    0.702035  0.576640   0.754717     1.000000  0.354181
# floors         0.256893  0.175608   0.500754     0.354181  1.000000
# waterfront     0.266371 -0.006591   0.063747     0.103817  0.023731
# view           0.397409  0.079411   0.187892     0.284627  0.029383
# grade          0.667541  0.357143   0.665029     0.762893  0.458074
# sqft_above     0.605559  0.477569   0.685376     0.876593  0.524117
# sqft_basement  0.323839  0.303093   0.283824     0.435061 -0.245646
# yr_built       0.054062  0.154410   0.506038     0.318253  0.489244
# yr_renovated   0.126489  0.018678   0.050880     0.055299  0.006193
# lat            0.307002 -0.008970   0.024587     0.052514  0.049595
# ...

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# 0      221900.0         3       1.00         1180     1.0           0     0
# 1      538000.0         3       2.25         2570     2.0           0     0
# 2      180000.0         2       1.00          770     1.0           0     0
# 3      604000.0         4       3.00         1960     1.0           0     0
# 4      510000.0         3       2.00         1680     1.0           0     0
# ...         ...       ...        ...          ...     ...         ...   ...
# 21608  360000.0         3       2.50         1530     3.0           0     0
# 21609  400000.0         4       2.50         2310     2.0           0     0
# 21610  402101.0         2       0.75         1020     2.0           0     0
# 21611  400000.0         3       2.50         1600     2.0           0     0
# 21612  325000.0         2       0.75         1020     2.0           0     0
#
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'sqft_living'}>],
#        [<Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>,
#         <Axes: title={'center': 'grade'}>],
#        [<Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>,
#         <Axes: title={'center': 'yr_built'}>,
#         <Axes: title={'center': 'yr_renovated'}>],
#        [<Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>, <Axes: >]],
#       dtype=object)

# %%
sns.scatterplot(x="bathrooms",y="sqft_living",data=df,hue="price")
plt.show()

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# 0      221900.0         3       1.00         1180     1.0           0     0
# 1      538000.0         3       2.25         2570     2.0           0     0
# 2      180000.0         2       1.00          770     1.0           0     0
# 3      604000.0         4       3.00         1960     1.0           0     0
# 4      510000.0         3       2.00         1680     1.0           0     0
# ...         ...       ...        ...          ...     ...         ...   ...
# 21608  360000.0         3       2.50         1530     3.0           0     0
# 21609  400000.0         4       2.50         2310     2.0           0     0
# 21610  402101.0         2       0.75         1020     2.0           0     0
# 21611  400000.0         3       2.50         1600     2.0           0     0
# 21612  325000.0         2       0.75         1020     2.0           0     0
#
# ...

# %%
df["waterfront"].unique()
# Out:
# array([0, 1])

# %%
df["waterfront"].value_counts()
# Out:
# 0    21445
# 1      163
# Name: waterfront, dtype: int64

# %%
df["view"].value_counts()
# Out:
# 0    19485
# 2      963
# 3      509
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
x=df.drop("price",axis=1)
y=df["price"]

# %%
x
# Out:
#        bedrooms  bathrooms  sqft_living  floors  waterfront  view  grade  \
# 0             3       1.00         1180     1.0           0     0      7
# 1             3       2.25         2570     2.0           0     0      7
# 2             2       1.00          770     1.0           0     0      6
# 3             4       3.00         1960     1.0           0     0      7
# 4             3       2.00         1680     1.0           0     0      8
# ...         ...        ...          ...     ...         ...   ...    ...
# 21608         3       2.50         1530     3.0           0     0      8
# 21609         4       2.50         2310     2.0           0     0      8
# 21610         2       0.75         1020     2.0           0     0      7
# 21611         3       2.50         1600     2.0           0     0      8
# 21612         2       0.75         1020     2.0           0     0      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated      lat     long  \
# ...

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21608, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler   #

std_x =StandardScaler()
x_std = std_x.fit_transform(x)

# y = y.values.reshape(-1, 1)
# y_std = std_x.fit_transform(y)

# %%
x_std
# Out:
# array([[-0.39881195, -1.44729656, -0.97983025, ..., -0.35251483,
#         -0.30608897, -0.94335843],
#        [-0.39881195,  0.17561515,  0.53353216, ...,  1.16146882,
#         -0.74634576, -0.4327119 ],
#        [-1.47398707, -1.44729656, -1.42621773, ...,  1.2834246 ,
#         -0.13566699,  1.0700479 ],
#        ...,
#        [-1.47398707, -1.77187891, -1.15403024, ...,  0.24788288,
#         -0.60432744, -1.41023526],
#        [-0.39881195,  0.50019749, -0.52255528, ..., -0.1843746 ,
#          1.02888321, -0.84122912],
#        [-1.47398707, -1.77187891, -1.15403024, ...,  0.24571799,
#         -0.60432744, -1.41023526]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_std,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# array([[ 1.75153829,  4.07060326,  3.27718201, ...,  0.50261893,
#         -0.01495142,  2.6895269 ],
#        [-1.47398707, -0.79813188, -0.50078028, ...,  0.21035803,
#         -0.6753366 , -0.4764816 ],
#        [-0.39881195,  0.50019749,  0.31578218, ..., -0.23128067,
#          0.30458979,  0.74907008],
#        ...,
#        [ 0.67636317, -0.47354954, -0.83829276, ...,  1.41331834,
#         -0.08596058,  0.42809226],
#        [-2.54916219, -1.77187891, -1.85083021, ..., -0.57044765,
#         -0.77474942, -1.19138675],
#        [ 0.67636317,  1.79852686,  1.86180709, ...,  0.71189217,
#          1.36262626,  2.07675106]])

# %%
y_train
# Out:
# 16969    3100000.0
# 6250      525000.0
# 13664     655000.0
# 7243      444000.0
# 17291     624900.0
#            ...
# 11966     550000.0
# 21580     594866.0
# 5392      323000.0
# 860       245000.0
# 15798    1295000.0
# Name: price, Length: 17286, dtype: float64

# %%
x_test
# Out:
# array([[ 0.67636317,  1.14936218,  1.6440571 , ...,  1.41187508,
#          1.26321343,  1.1721772 ],
#        [-0.39881195, -0.79813188, -0.83829276, ...,  0.96951474,
#         -0.84575858, -0.4473018 ],
#        [-0.39881195, -0.79813188, -0.41368028, ..., -1.72578026,
#         -0.88126316, -0.418122  ],
#        ...,
#        [ 0.67636317,  0.50019749,  0.67615841, ..., -1.96824857,
#          0.2619843 ,  0.84536342],
#        [-0.39881195,  0.50019749, -0.63143027, ...,  1.37074206,
#          0.26908521, -0.418122  ],
#        [-0.39881195, -0.47354954, -0.77296777, ..., -2.18329486,
#         -0.69663935, -0.72450992]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# model=LogisticRegression()
# model=DecisionTreeClassifier()
model = RandomForestRegressor()
model.fit(x_train,y_train)
print(model.score(x_train,y_train)*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Desktop\Sam(HOUSE PREDICTION)\FILE1_IPYNB.ipynb Cell 38 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/Sam%28HOUSE%20PREDICTION%29/FILE1_IPYNB.ipynb#X52sZmlsZQ%3D%3D?line=5'>6</a> # model=LogisticRegression()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/Sam%28HOUSE%20PREDICTION%29/FILE1_IPYNB.ipynb#X52sZmlsZQ%3D%3D?line=6'>7</a> # model=DecisionTreeClassifier()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/Sam%28HOUSE%20PREDICTION%29/FILE1_IPYNB.ipynb#X52sZmlsZQ%3D%3D?line=7'>8</a> model = RandomForestRegressor()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/Sam%28HOUSE%20PREDICTION%29/FILE1_IPYNB.ipynb#X52sZmlsZQ%3D%3D?line=8'>9</a> model.fit(x_train,y_train)
# ...

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([866658.54, 504586.69, 240461.5 , ..., 328519.3 , 376217.25,
#        239768.47])

# %%
y_test
# Out:
# 9399     879000.0
# 18667    526500.0
# 9996     262000.0
# 10973    595000.0
# 3043     430000.0
#            ...
# 12936    360000.0
# 2522     356500.0
# 21155    270000.0
# 16295    405000.0
# 17613    320000.0
# Name: price, Length: 4322, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test, prediction)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 18895580555.85732

# %%
mae = mean_absolute_error(y_test, prediction)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 75180.14563078436

# %%
r2 = r2_score(y_test, prediction)
print("R-squared:", r2)
# Out:
# R-squared: 0.8672749794392611

# %%
import matplotlib.pyplot as plt

plt.plot(y_test, prediction)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
# from sklearn.metrics import accuracy_score
# from sklearn import metrics as ms
# model_accuracy = ms.accuracy_score(y_test,prediction)*100
# model_accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-fbf396ca9369> in <cell line: 3>()
#       1 from sklearn.metrics import accuracy_score
#       2 from sklearn import metrics as ms
# ----> 3 model_accuracy = ms.accuracy_score(y_test,prediction)*100
#       4 model_accuracy
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     190
#     191             try:
# --> 192                 return func(*args, **kwargs)
#     193             except InvalidParameterError as e:
#     194                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     219
#     220     # Compute accuracy for each possible representation
# ...

# %%
prediction

# %%
y_test
